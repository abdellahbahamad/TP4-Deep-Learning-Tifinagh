# %%
import numpy as np
import os
import cv2
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

"""## Chargement et adaptation des données"""

def upload_data(path_name, number_of_images_per_class):
    X_Data = []
    Y_Data = []
    if not os.path.exists(path_name):
        print(f"Erreur : Le chemin n'existe pas : {path_name}")
        return np.array([]), np.array([])
    print(f"Analyse du chemin : {path_name}")
    # Obtenir dynamiquement tous les sous-dossiers comme catégories
    categories = [d for d in os.listdir(path_name) if os.path.isdir(os.path.join(path_name, d))]
    if not categories:
        print(f"Aucun sous-dossier trouvé dans {path_name}")
        return np.array([]), np.array([])
    print(f"Catégories détectées : {categories}")
    for idx, category in enumerate(categories):
        category_path = os.path.join(path_name, category)
        if os.path.isdir(category_path):
            images = [f for f in os.listdir(category_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
            print(f"Trouvé {len(images)} images dans {category}")
            if images:
                images_to_use = images[:min(number_of_images_per_class, len(images))]  # Limiter au nombre d'images disponibles
                for img_file in images_to_use:
                    img_path = os.path.join(category_path, img_file)
                    img = cv2.imread(img_path, 0)  # Charger en niveaux de gris
                    if img is not None:
                        # Redimensionner l'image à 28x28 pour correspondre à l'entrée du CNN
                        img_resized = cv2.resize(img, (28, 28))
                        X_Data.append(img_resized)
                        Y_Data.append(idx)
                    else:
                        print(f"Échec du chargement de l'image : {img_path}")
                print(f"> Chargé {len(images_to_use)} images de la classe {category}.", end='\r')
            else:
                print(f"Aucune image trouvée dans {category}")
        else:
            print(f"Dossier non trouvé pour la catégorie : {category}")
    return np.array(X_Data), np.array(Y_Data)

# Définir les paramètres
n_train = 200  # Réduit à un nombre sûr (ajuster selon la taille du dataset)
n_test = 50    # Réduit à un nombre sûr

# Mettre à jour les chemins pour correspondre à l'environnement Windows
train_path = r"C:\Users\Dell\Desktop\Tifinagh\train_data"
test_path = r"C:\Users\Dell\Desktop\Tifinagh\test_data"

# Charger les données d'entraînement et de test
print("Chargement des données d'entraînement...")
x_train, y_train = upload_data(train_path, n_train)
print("\nChargement des données de test...")
x_test, y_test = upload_data(test_path, n_test)

print("\nLa forme de x_train est :", x_train.shape)
print("La forme de x_test est :", x_test.shape)
print("La forme de y_train est :", y_train.shape)
print("La forme de y_test est :", y_test.shape)

def plot_data(num=3):
    if len(x_test) == 0:
        print("Erreur : x_test est vide, impossible d'afficher les données.")
        return
    fig, axes = plt.subplots(1, num, figsize=(12, 8))
    for i in range(num):
        index = np.random.randint(len(x_test))
        axes[i].imshow(x_test[index], cmap='gray')  # Déjà 28x28
        axes[i].set_title('Étiquette de l\'image : %d' % y_test[index])
        axes[i].axis('off')
    plt.show()

if x_test.size > 0:
    plot_data(num=5)

# Détecter dynamiquement le nombre de classes à partir de test_path
n_class = len([d for d in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, d))]) if os.path.exists(test_path) and os.listdir(test_path) else 0
print(f"Nombre de classes détectées : {n_class}")

# Prétraiter les données
if x_train.size > 0 and x_test.size > 0:
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    # Redimensionner pour CNN (échantillons, hauteur, largeur, canaux)
    x_train = np.expand_dims(x_train, axis=-1)
    x_test = np.expand_dims(x_test, axis=-1)
    x_train /= 255
    x_test /= 255
    print('Forme de x_train :', x_train.shape)
    print(x_train.shape[0], 'échantillons d\'entraînement')
    print(x_test.shape[0], 'échantillons de test')

    # Vérifier les valeurs des étiquettes
    if np.max(y_train) >= n_class or np.max(y_test) >= n_class:
        print(f"Erreur : Les étiquettes contiennent des valeurs ({np.max(y_train)}, {np.max(y_test)}) supérieures ou égales à n_class ({n_class}). Ajustez n_class ou vérifiez les données.")
    else:
        # Convertir les vecteurs de classes en matrices de classes binaires
        y_train = to_categorical(y_train, n_class)
        y_test = to_categorical(y_test, n_class)

        """## Architecture du modèle"""

        def define_model(input_size=(28, 28, 1)):
            inputs = Input(input_size)
            conv1 = Conv2D(128, 3, activation='relu', padding='same')(inputs)
            conv1 = Conv2D(128, 3, activation='relu', padding='same')(conv1)
            pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

            conv3 = Conv2D(64, 3, activation='relu', padding='same')(pool1)
            conv3 = Conv2D(64, 3, activation='relu', padding='same')(conv3)
            pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

            conv4 = Conv2D(32, 3, activation='relu', padding='same')(pool3)

            fltt = Flatten()(conv4)

            dan = Dense(n_class, activation='softmax')(fltt)

            model = Model(inputs=inputs, outputs=dan)

            model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

            return model

        model = define_model((28, 28, 1))
        model.summary()

        # Entraîner le modèle
        history = model.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_test, y_test))

        """## Prédiction du modèle sur les données de test après entraînement"""

        def plot_predictions(model, num=3):
            if len(x_test) == 0:
                print("Erreur : x_test est vide, impossible d'afficher les prédictions.")
                return
            fig, axes = plt.subplots(1, num, figsize=(12, 8))
            for i in range(num):
                index = np.random.randint(len(x_test))
                pred = np.argmax(model.predict(np.expand_dims(x_test[index], 0)))
                axes[i].imshow(x_test[index].reshape(28, 28), cmap='gray')
                axes[i].set_title('Étiquette prédite : ' + str(pred) + '\nÉtiquette réelle : ' + str(np.argmax(y_test[index])))
                axes[i].axis('off')
            plt.show()

        plot_predictions(model, num=5)
        score = model.evaluate(x_test, y_test, verbose=0)
        print('Perte sur les tests :', score[0])
        print('Précision sur les tests :', score[1])

        """## Historique du modèle pendant l'entraînement"""

        # Supprimé le style xkcd pour éviter les avertissements de police
        plt.plot(history.history['accuracy'], color='c')
        plt.plot(history.history['val_accuracy'], color='red')
        plt.title('Précision du modèle Tifinagh-MNIST')
        plt.legend(['préc', 'val_préc'])
        plt.savefig(os.path.join(r"C:\Users\Dell\Desktop\Tifinagh", 'acc_Tifinagh_cnn.png'))
        plt.show()

        plt.plot(history.history['loss'], color='c')
        plt.plot(history.history['val_loss'], color='red')
        plt.title('Perte du modèle Tifinagh')
        plt.legend(['perte', 'val_perte'])
        plt.savefig(os.path.join(r"C:\Users\Dell\Desktop\Tifinagh", 'loss_Tifinagh_cnn.png'))
        plt.show()
else:
    print("Erreur : Données insuffisantes pour procéder à l'entraînement du modèle.")
# Out:
# Chargement des données d'entraînement...
# Analyse du chemin : C:\Users\Dell\Desktop\Tifinagh\train_data
# Catégories détectées : ['ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagg', 'yagh', 'yah', 'yahh', 'yaj', 'yak', 'yakk', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
# Trouvé 854 images dans ya
# Trouvé 854 images dans yabclasse ya.
# Trouvé 854 images dans yachlasse yab.
# Trouvé 854 images dans yadclasse yach.
# Trouvé 854 images dans yaddlasse yad.
# Trouvé 854 images dans yaeclasse yadd.
# Trouvé 854 images dans yafclasse yae.
# Trouvé 854 images dans yagclasse yaf.
# Trouvé 854 images dans yagglasse yag.
# Trouvé 854 images dans yaghlasse yagg.
# Trouvé 854 images dans yahclasse yagh.
# Trouvé 854 images dans yahhlasse yah.
# Trouvé 854 images dans yajclasse yahh.
# Trouvé 854 images dans yakclasse yaj.
# Trouvé 854 images dans yakklasse yak.
# Trouvé 854 images dans yalclasse yakk.
# Trouvé 854 images dans yamclasse yal.
# Trouvé 854 images dans yanclasse yam.
# Trouvé 854 images dans yaqclasse yan.
# Trouvé 854 images dans yarclasse yaq.
# Trouvé 854 images dans yarrlasse yar.
# Trouvé 854 images dans yasclasse yarr.
# Trouvé 854 images dans yasslasse yas.
# Trouvé 854 images dans yatclasse yass.
# Trouvé 854 images dans yattlasse yat.
# Trouvé 854 images dans yawclasse yatt.
# Trouvé 854 images dans yaxclasse yaw.
# Trouvé 854 images dans yayclasse yax.
# Trouvé 854 images dans yazclasse yay.
# Trouvé 854 images dans yazzlasse yaz.
# Trouvé 854 images dans yeyclasse yazz.
# Trouvé 854 images dans yi classe yey.
# Trouvé 854 images dans yu classe yi.
# > Chargé 200 images de la classe yu.
# Chargement des données de test...
# Analyse du chemin : C:\Users\Dell\Desktop\Tifinagh\test_data
# Catégories détectées : ['.ipynb_checkpoints', 'ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagg', 'yagh', 'yah', 'yahh', 'yaj', 'yak', 'yakk', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
# Trouvé 0 images dans .ipynb_checkpoints
# Aucune image trouvée dans .ipynb_checkpoints
# Trouvé 854 images dans ya
# Trouvé 854 images dans yablasse ya.
# Trouvé 854 images dans yachasse yab.
# Trouvé 854 images dans yadlasse yach.
# Trouvé 854 images dans yaddasse yad.
# Trouvé 854 images dans yaelasse yadd.
# Trouvé 854 images dans yaflasse yae.
# Trouvé 854 images dans yaglasse yaf.
# Trouvé 854 images dans yaggasse yag.
# Trouvé 854 images dans yaghasse yagg.
# Trouvé 854 images dans yahlasse yagh.
# Trouvé 854 images dans yahhasse yah.
# Trouvé 854 images dans yajlasse yahh.
# Trouvé 854 images dans yaklasse yaj.
# Trouvé 854 images dans yakkasse yak.
# Trouvé 854 images dans yallasse yakk.
# Trouvé 854 images dans yamlasse yal.
# Trouvé 854 images dans yanlasse yam.
# Trouvé 854 images dans yaqlasse yan.
# Trouvé 854 images dans yarlasse yaq.
# Trouvé 854 images dans yarrasse yar.
# Trouvé 854 images dans yaslasse yarr.
# Trouvé 854 images dans yassasse yas.
# Trouvé 854 images dans yatlasse yass.
# Trouvé 854 images dans yattasse yat.
# Trouvé 854 images dans yawlasse yatt.
# Trouvé 854 images dans yaxlasse yaw.
# Trouvé 854 images dans yaylasse yax.
# Trouvé 854 images dans yazlasse yay.
# Trouvé 854 images dans yazzasse yaz.
# Trouvé 854 images dans yeylasse yazz.
# Trouvé 854 images dans yiclasse yey.
# Trouvé 854 images dans yuclasse yi.
# > Chargé 50 images de la classe yu.
# La forme de x_train est : (6600, 28, 28)
# La forme de x_test est : (1650, 28, 28)
# La forme de y_train est : (6600,)
# La forme de y_test est : (1650,)
# Nombre de classes détectées : 34
# Forme de x_train : (6600, 28, 28, 1)
# 6600 échantillons d'entraînement
# 1650 échantillons de test
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 128)    │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 32)       │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1568)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 34)             │        53,346 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 331,394 (1.26 MB)
#  Trainable params: 331,394 (1.26 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 54s 941ms/step - accuracy: 0.2042 - loss: 2.8964 - val_accuracy: 0.0139 - val_loss: 7.9693
# Epoch 2/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 48s 921ms/step - accuracy: 0.7038 - loss: 0.9278 - val_accuracy: 0.0121 - val_loss: 11.5483
# Epoch 3/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 47s 913ms/step - accuracy: 0.8758 - loss: 0.3750 - val_accuracy: 0.0048 - val_loss: 18.1603
# Epoch 4/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 47s 908ms/step - accuracy: 0.9460 - loss: 0.1716 - val_accuracy: 0.0055 - val_loss: 18.6153
# Epoch 5/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 47s 897ms/step - accuracy: 0.9633 - loss: 0.1011 - val_accuracy: 0.0030 - val_loss: 20.0616
# Epoch 6/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 49s 935ms/step - accuracy: 0.9714 - loss: 0.0885 - val_accuracy: 0.0000e+00 - val_loss: 22.5041
# Epoch 7/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 47s 911ms/step - accuracy: 0.9871 - loss: 0.0454 - val_accuracy: 0.0012 - val_loss: 22.8241
# Epoch 8/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 49s 940ms/step - accuracy: 0.9822 - loss: 0.0540 - val_accuracy: 0.0000e+00 - val_loss: 25.3611
# Epoch 9/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 48s 924ms/step - accuracy: 0.9942 - loss: 0.0226 - val_accuracy: 6.0606e-04 - val_loss: 23.5840
# Epoch 10/10
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 48s 915ms/step - accuracy: 0.9928 - loss: 0.0271 - val_accuracy: 0.0000e+00 - val_loss: 24.4086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Perte sur les tests : 24.408592224121094
# Précision sur les tests : 0.0
